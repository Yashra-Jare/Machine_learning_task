# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "https://drive.google.com/uc?export=download&id=1_LDFViFNgxB-mGOzN1fuwhepI2aeOIfp"

data = pd.read_csv(url)

# %% [markdown]
# 1 . plotting histograms

# %%
features = [data['Feature_1'], data['Feature_2'] , data['Feature_3']]

# %% [markdown]
# for feature_1 :-

# %%
plt.Figure(figsize=(5,5))
plt.hist(features[0] , bins=20 , color='blue')
plt.ylabel('frequency')
plt.xlabel('features_1')
plt.title('histogram of feature 1')
# Out:
# Text(0.5, 1.0, 'histogram of feature 1')

# %% [markdown]
# for feature_2 :-

# %%
plt.Figure(figsize=(5,5))
plt.hist(features[1] , bins=20 , color='blue')
plt.ylabel('frequency')
plt.xlabel('features_2')
plt.title('histogram of feature 2')
# Out:
# Text(0.5, 1.0, 'histogram of feature 2')

# %% [markdown]
# for feature_3 :-

# %%
plt.Figure(figsize=(5,5))
plt.hist(features[2] , bins=20 , color='blue')
plt.ylabel('frequency')
plt.xlabel('features_3')
plt.title('histogram of feature 3')
# Out:
# Text(0.5, 1.0, 'histogram of feature 3')

# %% [markdown]
# Correlation Heatmap

# %%
numeric_data = data.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_data.corr()

plt.figure(figsize=(15,15))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5, linecolor='white', square=True)
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# Box-Plot

# %% [markdown]
# for feature_1 :-

# %%
sns.boxplot(x='romantic', y=features[0], data=data)
plt.title('feature_1 vs Romantic Relationship Status')
plt.xlabel('Romantic Relationship (yes/no)')
plt.ylabel('feature_1')
# Out:
# Text(0, 0.5, 'feature_1')

# %% [markdown]
# for feature_2 :-

# %%
plt.Figure(figsize=(5,5))
sns.boxplot(x='romantic', y=features[1], data=data)
plt.title('feature_2 vs Romantic Relationship Status')
plt.xlabel('Romantic Relationship (yes/no)')
plt.ylabel('feature_2')
# Out:
# Text(0, 0.5, 'feature_2')

# %% [markdown]
# for feature_3 :-

# %%
plt.Figure(figsize=(5,5))
sns.boxplot(x='romantic', y=features[2], data=data)
plt.title('feature_3 vs Romantic Relationship Status')
plt.xlabel('Romantic Relationship (yes/no)')
plt.ylabel('feature_3')
# Out:
# Text(0, 0.5, 'feature_3')

# %% [markdown]
# ## Level 2 :

# %% [markdown]
# Calculating Missing values

# %%
data.isnull().sum()
# Out:
# school         0
# sex            0
# address        0
# famsize       50
# Pstatus        0
# Medu           0
# Fedu          73
# Mjob           0
# Fjob           0
# reason         0
# guardian       0
# traveltime    73
# failures       0
# schoolsup      0
# famsup         0
# paid           0
# activities     0
# nursery        0
# higher        76
# internet       0
# famrel         0
# freetime      45
# goout          0
# Dalc           0
# health         0
# absences      69
# G1             0
# G2            35
# G3             0
# Feature_1     38
# Feature_2     46
# Feature_3     39
# romantic       0
# dtype: int64

# %% [markdown]
# Filling missing values.

# %%
data['famsize'].fillna(data['famsize'].mode()[0], inplace = True)
# Out:
# <ipython-input-12-97bf348e2a39>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['famsize'].fillna(data['famsize'].mode()[0], inplace = True)

# %%
data['higher'].fillna(data['higher'].mode()[0], inplace = True)
# Out:
# <ipython-input-13-956a1f4788ca>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['higher'].fillna(data['higher'].mode()[0], inplace = True)

# %%
for col in ['Feature_1','G2']:
    data[col].fillna(data[col].mean(), inplace=True)
# Out:
# <ipython-input-14-2e4f3434edfd>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[col].fillna(data[col].mean(), inplace=True)

# %%
for col in ['Fedu', 'traveltime', 'absences', 'freetime', 'Feature_2', 'Feature_3']:
    data[col].fillna(data[col].median(), inplace=True)
# Out:
# <ipython-input-15-c4c4a957568e>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[col].fillna(data[col].median(), inplace=True)

# %% [markdown]
# ## Level 3 :

# %% [markdown]
# Q1: Does drinking alcohol affect how well students do in academics ?

# %%
# violin Plot between dalc and G3

plt.figure(figsize=(5, 5))
sns.violinplot( x='Dalc', y='G3', data= data, palette='Set2')
plt.title('Grades vs alcohol consumption')
plt.xlabel('Alcohol Consumption')
plt.ylabel('Grade (G3)')
# Out:
# <ipython-input-16-0b5c0681a455>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot( x='Dalc', y='G3', data= data, palette='Set2')
# Text(0, 0.5, 'Grade (G3)')

# %% [markdown]
# Q2: Are students from urban areas more likely to be in romantic relationships than those from rural areas?

# %%
in_relationship = data[data['romantic']=='Yes']
counts = data['address'].value_counts()

plt.figure(figsize=(5,5))
plt.bar(counts.index, counts.values, color=['blue', 'red'])
plt.title('Number of Students in Relationship by Address')
plt.xlabel('Address')
plt.ylabel('Number of Students')
# Out:
# Text(0, 0.5, 'Number of Students')

# %% [markdown]
# Q3: How does parental cohabitation status relate to stress levels among students?

# %%
together_parents = data.loc[data['Pstatus'] == 'T', 'Feature_2'].value_counts().sort_index()
separated_parents = data.loc[data['Pstatus'] == 'A', 'Feature_2'].value_counts().sort_index()

plt.subplot(1, 2, 1)
plt.bar(together_parents.index , together_parents.values ,color='blue')
plt.title('Stress Levels for  Together')
plt.xlabel('Stress Level')
plt.ylabel('Number of Students')
plt.xticks(features[1])

plt.subplot(1, 2, 2)
plt.bar(separated_parents.index , separated_parents.values , color='red')
plt.title('Stress Levels for Separated')
plt.xlabel('Stress Level')
plt.ylabel('Number of Students')
plt.xticks(features[1])

plt.tight_layout()

# %% [markdown]
# Q4:  Does internet access at home affect academic performance?

# %%
sns.violinplot(x='internet', y='G3', data=data)
plt.title("Grades by Internet Access at Home")
plt.xlabel('Internet Access')
plt.ylabel('Grades')
plt.title('Grades by Internet Access at Home')
# Out:
# Text(0.5, 1.0, 'Grades by Internet Access at Home')

# %% [markdown]
# Q5:  Does being in a romantic relationship impacts on student's final grades?

# %%
plt.figure(figsize=(5, 5))
sns.boxplot( x='romantic', y='G3',data=data , palette='pastel')
plt.title("Romantic Relationship vs Final Grades")
plt.xlabel("Relationship status")
plt.ylabel("Final Grade")
# Out:
# <ipython-input-20-d7289436599f>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot( x='romantic', y='G3',data=data , palette='pastel')
# Text(0, 0.5, 'Final Grade')

# %% [markdown]
# ## Level 4 :

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# Encoding the data:

# %%
X = data.iloc[: , : -1]
Y = data.loc[: , 'romantic']

X= pd.get_dummies( X)

# %% [markdown]
# splitting the data

# %%
X_train , X_test , Y_train , Y_test =train_test_split(X ,Y , test_size=0.3 ,random_state=99)

# %% [markdown]
# Forming the model

# %%
LogisticRegression_model = LogisticRegression()
Random_forest_model = RandomForestClassifier()

LogisticRegression_model.fit(X_train ,Y_train)
Random_forest_model.fit(X_train ,Y_train)

y_pred_logreg = LogisticRegression_model.predict(X_test)
y_pred_rf = Random_forest_model.predict(X_test)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# Accuracy of Models

# %%
print( "accuracy of Logistic regression model : ",accuracy_score(Y_test ,y_pred_logreg) * 100)
print( "accuracy of Random forest model : ",accuracy_score(Y_test ,y_pred_rf) * 100)
# Out:
# accuracy of Logistic regression model :  61.02564102564103
# accuracy of Random forest model :  58.97435897435898

# %% [markdown]
# Weightage of Features

# %%
imp_features_Logreg_model = pd.Series(abs(LogisticRegression_model.coef_[0]), index=X.columns)
imp_features_Logreg_model_order= imp_features_Logreg_model.sort_values(ascending=False)

imp_features_rf_model = pd.Series(Random_forest_model.feature_importances_, index=X.columns)
imp_features_rf_model_order= imp_features_rf_model.sort_values(ascending=False)

print('IMP features of Logistic_regression_model\n' ,imp_features_Logreg_model_order,'\n\n')
print('IMP features of Random forest_model\n',imp_features_rf_model_order)
# Out:
# IMP features of Logistic_regression_model
#  Mjob_services        0.629382
# Mjob_health          0.612590
# guardian_other       0.498278
# guardian_father      0.448624
# Fjob_teacher         0.423834
# paid_no              0.418986
# Fjob_at_home         0.389847
# Mjob_teacher         0.386541
# Pstatus_T            0.379846
# sex_M                0.374384
# schoolsup_yes        0.352747
# school_GP            0.337817
# guardian_mother      0.325858
# internet_no          0.312277
# address_R            0.274296
# Feature_2            0.258383
# famsize_LE3          0.250881
# nursery_yes          0.250380
# famsup_yes           0.249312
# activities_no        0.248071
# Fjob_other           0.209856
# higher_yes           0.204780
# reason_reputation    0.191361
# G2                   0.188919
# Fedu                 0.184003
# Feature_1            0.170744
# freetime             0.162879
# Mjob_other           0.150101
# paid_yes             0.142782
# reason_course        0.117414
# Medu                 0.111139
# Pstatus_A            0.103643
# sex_F                0.098180
# Dalc                 0.096272
# Fjob_health          0.085569
# failures             0.082810
# schoolsup_no         0.076543
# higher_no            0.071424
# G1                   0.068609
# health               0.065760
# school_MS            0.061613
# reason_other         0.051753
# Feature_3            0.046942
# goout                0.044682
# absences             0.043473
# traveltime           0.036607
# internet_yes         0.036074
# activities_yes       0.028132
# famsup_no            0.026891
# nursery_no           0.025824
# famsize_GT3          0.025323
# Mjob_at_home         0.022972
# reason_home          0.019181
# Fjob_services        0.014765
# G3                   0.006826
# address_U            0.001907
# famrel               0.001451
# dtype: float64
#
#
# IMP features of Random forest_model
#  G2                   0.058911
# G3                   0.049692
# absences             0.049245
# Feature_1            0.048182
# G1                   0.047941
# Feature_2            0.036444
# Fedu                 0.036179
# Feature_3            0.035233
# goout                0.034779
# health               0.032773
# freetime             0.032263
# Medu                 0.030392
# famrel               0.029242
# traveltime           0.025361
# Dalc                 0.021544
# guardian_other       0.015078
# Mjob_services        0.014573
# activities_yes       0.014425
# Mjob_other           0.014205
# activities_no        0.013582
# failures             0.013158
# sex_F                0.012950
# sex_M                0.012920
# Pstatus_A            0.012702
# school_GP            0.012629
# famsup_yes           0.012578
# reason_course        0.012536
# guardian_mother      0.012263
# famsup_no            0.012095
# address_R            0.012055
# school_MS            0.012040
# nursery_no           0.011467
# reason_home          0.011461
# address_U            0.011385
# internet_yes         0.011113
# Fjob_other           0.010524
# guardian_father      0.010450
# nursery_yes          0.010409
# reason_other         0.010006
# Mjob_health          0.009797
# famsize_GT3          0.009711
# Fjob_services        0.009680
# reason_reputation    0.009516
# Mjob_at_home         0.009439
# famsize_LE3          0.009327
# internet_no          0.008999
# Pstatus_T            0.007582
# schoolsup_no         0.007541
# Fjob_at_home         0.007166
# higher_no            0.007107
# higher_yes           0.006935
# schoolsup_yes        0.006867
# Mjob_teacher         0.006586
# Fjob_teacher         0.005885
# paid_no              0.004979
# paid_yes             0.004670
# Fjob_health          0.003428
# dtype: float64

# %% [markdown]
# ##  Level 5: Model Reasoning & Interpretation

# %% [markdown]
# Decision boundary for 'Feature_1' and 'goout'

# %%
data['romantic'] = data['romantic'].map({'yes': 1, 'no': 0})

feature_pair = data[['Feature_1', 'goout']].values
target = data['romantic'].values

# creating meshgrid
feature_pair_min, feature_pair_max = feature_pair[:, 0].min() - 1, feature_pair[:, 0].max() + 1
target_min, target_max = feature_pair[:, 1].min() - 1, feature_pair[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(feature_pair_min, feature_pair_max, 0.1),
                     np.arange(target_min, target_max, 0.1))
grid = np.c_[xx.ravel(), yy.ravel()]

# %% [markdown]
# For RandomForest_model

# %%
rf_model = RandomForestClassifier()
rf_model.fit(feature_pair, target)
Z =rf_model.predict(grid)
Z = Z.reshape(xx.shape)

plt.figure(figsize=(5, 5))
plt.contourf(xx, yy, Z, alpha=0.3, cmap='coolwarm')
plt.scatter(feature_pair[:, 0], feature_pair[:, 1], c=target, cmap='coolwarm')
plt.xlabel("Feature_1")
plt.ylabel("goout")
plt.title("Decision Boundary for Feature_1 and goout")
# Out:
# Text(0.5, 1.0, 'Decision Boundary for Feature_1 and goout')

# %% [markdown]
# For Logistic regression model

# %%
lrg_model = LogisticRegression()
lrg_model.fit(feature_pair, target)
p =lrg_model.predict(grid)
p = p.reshape(xx.shape)

plt.figure(figsize=(5, 5))
plt.contourf(xx, yy, p, alpha=0.3, cmap='coolwarm')
plt.scatter(feature_pair[:, 0], feature_pair[:, 1], c=target, cmap='coolwarm')
plt.xlabel("Feature_1")
plt.ylabel("goout")
plt.title("Decision Boundary for Feature_1 and goout")
# Out:
# Text(0.5, 1.0, 'Decision Boundary for Feature_1 and goout')

# %% [markdown]
# Using Shap for logistic regression model

# %%
import shap

lrg_explainer = shap.Explainer(LogisticRegression_model, X_train)
lrg_shap_values = lrg_explainer(X_train)

shap.plots.bar(lrg_shap_values)

# %%
idx_yes = np.where(y_pred_logreg=="yes" )[0][0]
idx_no = np.where(y_pred_logreg == "no")[0][0]


print("SHAP Explanation for a student predicted YES:")
shap.plots.waterfall(lrg_shap_values[idx_yes])

print("SHAP Explanation for a student predicted NO:")
shap.plots.waterfall(lrg_shap_values[idx_no])
# Out:
# SHAP Explanation for a student predicted YES:
# SHAP Explanation for a student predicted NO:
